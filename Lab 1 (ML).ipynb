# %%
import tensorflow as tf
import numpy as np
import time

# %%
z=np.array([7,21,-18,36,2,-28,-85,-92,17,-58],dtype=float)
inputs=np.array([(3,5),(4,2),(7,20),(13,12),(23,40),(-1,10),(-22,-6),(-21,-2),(2,0),(5,30)],dtype=float)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1, input_shape=[2])
])

# %%
model.compile(
    loss='mean_squared_error',
    optimizer=tf.keras.optimizers.Adam(0.1))

# %%
t=time.time()
hist = model.fit(inputs , z , epochs=1000, verbose=0)
x=time.time()-t
print(f"Training took : {x} sec")
# Out:
# Training took : 3.3349575996398926 sec

# %%
hist.history['loss']
# Out:
# [2585.63818359375,
#  2476.9716796875,
#  2381.076171875,
#  2287.12255859375,
#  2192.385009765625,
#  2098.1171875,
#  2005.4427490234375,
#  1915.1029052734375,
#  1827.5325927734375,
#  1742.900634765625,
#  1661.139892578125,
#  1582.0152587890625,
#  1505.247802734375,
#  1430.658203125,
#  1358.241455078125,
#  1288.13671875,
#  1220.5272216796875,
#  1155.5345458984375,
#  1093.161865234375,
#  1033.30224609375,
#  975.8020629882812,
#  920.5301513671875,
#  867.4230346679688,
#  816.4827270507812,
#  767.7496337890625,
#  721.2618408203125,
#  677.0228881835938,
#  634.9868774414062,
#  595.0668334960938,
#  557.160888671875,
#  521.1821899414062,
#  487.07586669921875,
#  454.81597900390625,
#  424.3844299316406,
#  395.74908447265625,
#  368.8504943847656,
#  343.6065368652344,
#  319.9276428222656,
#  297.7340087890625,
#  276.964599609375,
#  257.5730895996094,
#  239.5174102783203,
#  222.7469940185547,
#  207.1983642578125,
#  192.79832458496094,
#  179.4730987548828,
# ...

# %%
import matplotlib.pyplot as plt
plt.xlabel('Epoch Number')
plt.ylabel('Loss Magnitude')
plt.plot(hist.history['loss'])

# %%
model.get_weights()
# Out:
# [array([[ 4.9999986],
#         [-2.999999 ]], dtype=float32),
#  array([6.999983], dtype=float32)]

# %%
model.predict(np.array([(7,10)]))
# Out:
# 1/1 [==============================] - 0s 18ms/step
# array([[11.999981]], dtype=float32)
